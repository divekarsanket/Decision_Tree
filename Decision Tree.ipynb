# %%
import pandas as pd

# %%
df = pd.read_csv("salaries.csv")
df
# Out:
#     company         job               degree  company_n  Salary_more_than_100k
# 0         0      google      sales executive  bachelors                      0
# 1         1      google      sales executive    masters                      0
# 2         2      google     business manager  bachelors                      1
# 3         3      google     business manager    masters                      1
# 4         4      google  computer programmer  bachelors                      0
# 5         5      google  computer programmer    masters                      1
# 6         6  abc pharma      sales executive    masters                      0
# 7         7  abc pharma  computer programmer  bachelors                      0
# 8         8  abc pharma     business manager  bachelors                      0
# 9         9  abc pharma     business manager    masters                      1
# 10       10    facebook      sales executive  bachelors                      1
# 11       11    facebook      sales executive    masters                      1
# 12       12    facebook     business manager  bachelors                      1
# 13       13    facebook     business manager    masters                      1
# 14       14    facebook  computer programmer  bachelors                      1
# 15       15    facebook  computer programmer    masters                      1

# %%
inputs = df.drop('Salary_more_than_100k',axis='columns')

# %%
target = df['Salary_more_than_100k']

# %%
from sklearn.preprocessing import LabelEncoder
le_company = LabelEncoder()
le_job = LabelEncoder()
le_degree = LabelEncoder()

# %%
inputs['company_n'] = le_company.fit_transform(inputs['company'])
inputs['job_n'] = le_job.fit_transform(inputs['job'])
inputs['degree_n'] = le_degree.fit_transform(inputs['degree'])

# %%
inputs
# Out:
#     company         job               degree  company_n  job_n  degree_n
# 0         0      google      sales executive          0      2         2
# 1         1      google      sales executive          1      2         2
# 2         2      google     business manager          2      2         0
# 3         3      google     business manager          3      2         0
# 4         4      google  computer programmer          4      2         1
# 5         5      google  computer programmer          5      2         1
# 6         6  abc pharma      sales executive          6      0         2
# 7         7  abc pharma  computer programmer          7      0         1
# 8         8  abc pharma     business manager          8      0         0
# 9         9  abc pharma     business manager          9      0         0
# 10       10    facebook      sales executive         10      1         2
# 11       11    facebook      sales executive         11      1         2
# 12       12    facebook     business manager         12      1         0
# 13       13    facebook     business manager         13      1         0
# 14       14    facebook  computer programmer         14      1         1
# 15       15    facebook  computer programmer         15      1         1

# %%
inputs_n = inputs.drop(['company','job','degree'],axis='columns')
inputs_n
# Out:
#     company_n  job_n  degree_n
# 0           0      2         2
# 1           1      2         2
# 2           2      2         0
# 3           3      2         0
# 4           4      2         1
# 5           5      2         1
# 6           6      0         2
# 7           7      0         1
# 8           8      0         0
# 9           9      0         0
# 10         10      1         2
# 11         11      1         2
# 12         12      1         0
# 13         13      1         0
# 14         14      1         1
# 15         15      1         1

# %%
target
# Out:
# 0     0
# 1     0
# 2     1
# 3     1
# 4     0
# 5     1
# 6     0
# 7     0
# 8     0
# 9     1
# 10    1
# 11    1
# 12    1
# 13    1
# 14    1
# 15    1
# Name: Salary_more_than_100k, dtype: int64

# %%
from sklearn import tree
model = tree.DecisionTreeClassifier()

# %%
model.fit(inputs_n, target)
# Out:
# DecisionTreeClassifier()

# %%
#Is salary of Google, Computer Engineer, Bachelors degree > 100 k ?
model.predict([[2,1,0]])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([0], dtype=int64)

# %%
#Is salary of Google, Computer Engineer, Masters degree > 100 k ?
model.predict([[2,1,1]])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([0], dtype=int64)

# %%
model.score(inputs_n,target)
